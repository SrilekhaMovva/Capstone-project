# %%
import pandas as pd
import numpy as np
import glob

# %%
import os
import shutil
import pandas as pd
def seperation(path):
    my_file = open(path, "r")
    Lines = my_file.readlines()
    file=[]
    for line in Lines:
        a= line.split()
        if a[1] =='11':
            shutil.copyfile("Desktop/images/"+a[0],destination+a[0].split('/')[-1])
            print(line)
            print("DONE")

# %%
destination="C:/Users/srilekha chowdary/Invoice data/test/imgs"     
seperation('test.txt')

# %%
destination="C:/Users/srilekha chowdary/Invoice data/train/imgs"
seperation('train.txt')

# %%
from PIL import Image
import glob
for file in glob.glob(r"C:\Users\srilekha chowdary\Invoicedata\test\imgs\*.tif"):
    im = Image.open(file)
    rgb_im = im.convert('RGB')
    rgb_im.save(file.replace("tif", "jpg"))
    print(file)
# Out:
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000023361.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000037007.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000037010.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000089370.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000102823.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000113725.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000113760.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000113778.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000137486.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000137523.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000137530.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000137558.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000138960.tif
# C:\Users\srilekha chowdary\Invoicedata\test\imgs\imgs0000145869.tif
# ...

# %%
for file in glob.glob(r"C:\Users\srilekha chowdary\Invoicedata\train\imgs\*.tif"):
    im = Image.open(file)
    rgb_im = im.convert('RGB')
    rgb_im.save(file.replace("tif", "jpg"))
    print(file)
# Out:
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000002350.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000002410.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000019626.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000020180.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000027283.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000027981.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000036367.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000036371.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000036968.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000037009.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000044003.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000049623.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000056826.tif
# C:\Users\srilekha chowdary\Invoicedata\train\imgs\imgs0000074370.tif
# ...
